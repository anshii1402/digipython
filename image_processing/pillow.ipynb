# %%
from PIL import Image, ImageFilter,ImageEnhance,ImageDraw,ImageFont

# %%
im1 = Image.open('img1.jpg')
im2 = Image.open('img2.jpg')
im3 = Image.open('img3.png')
im4 = Image.open('img4.png')

# %%
im4
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=128x128>

# %%
print(f"Im1 size in pixels: {im1.size}")
print(f"Im1 height is {im1.height}pixels")
print(f"im1 width is {im1.width}pixels")
print(f"im1 format is {im1.format}")
# Out:
# Im1 size in pixels: (480, 640)
# Im1 height is 640pixels
# im1 width is 480pixels
# im1 format is JPEG

# %%
im1.resize((300,300))
# Out:
# <PIL.Image.Image image mode=RGB size=300x300>

# %%
#resize by 50%
w = im1.width / 2
h = im1.height / 2
im1.resize((int(w),int(h)))
# Out:
# <PIL.Image.Image image mode=RGB size=240x320>

# %%
im2.size
# Out:
# (640, 427)

# %%
#crop image
im2.crop((50 , 110 , 600 , 380))
# Out:
# <PIL.Image.Image image mode=RGB size=550x270>

# %%
im1.crop((0,0, im1.width,im1.height-500))
# Out:
# <PIL.Image.Image image mode=RGB size=480x140>

# %%
im1.rotate(180/2, expand = True)
# Out:
# <PIL.Image.Image image mode=RGB size=640x480>

# %%
im2.rotate(45, fillcolor='#4e4d53')
# Out:
# <PIL.Image.Image image mode=RGB size=640x427>

# %%
im1.transpose(Image.Transpose.FLIP_LEFT_RIGHT)
# Out:
# <PIL.Image.Image image mode=RGB size=480x640>

# %%
im1.transpose(Image.Transpose.FLIP_TOP_BOTTOM)
# Out:
# <PIL.Image.Image image mode=RGB size=480x640>

# %%
w = im1.width / 2
h = im1.height / 2
im1.resize((int(w),int(h))).crop((0,0,200,250)).save("im1_resized.jpg")

# %%
im5 = Image.open('img5.png')
im6 = Image.open('img6.png')

# %%
# 25% resize
w = im6.width / 4
h = im6.height / 4
logo = im6.resize((int(w),int(h)))
logo1 = im5.resize((int(w),int(h)))
logo.show()
logo1.show()

# %%
bg=im3.copy()
bg.paste(logo,(10,10),logo)
bg.paste(logo1,(500,750),logo1)

# %%
bg
# Out:
# <PIL.Image.Image image mode=RGB size=650x900>

# %%
# merging 2 images
im11 = im1.resize(im3.size)
im11.format = im3.format
im11.mode = im3.mode

# %%
Image.blend(im11, im3, 0.7).save("my_new_image.png")
